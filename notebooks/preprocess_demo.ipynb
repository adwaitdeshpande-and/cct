# %% [markdown]
# # Preprocess demo
# This notebook shows how to extract frames and hashes using `src.forensics.preprocess`.

# %%
from pathlib import Path
from src.forensics.preprocess import preprocess

input_path = Path('data/sample_videos/new_sample.mp4')
outdir = Path('outputs/notebook_preprocess')
outdir.mkdir(parents=True, exist_ok=True)
manifest = preprocess(input_path=input_path, outdir=outdir)
manifest
